# %%
#import & Check required libraries:
import sys
print('Python: {}'.format(sys.version))
# pip install scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# pip install numpy
import numpy
print('numpy: {}'.format(numpy.__version__))
# pip install matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pip install pandas
import pandas
print('pandas: {}'.format(pandas.__version__))
# pip install scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# scipy: 1.7.3
# numpy: 1.21.5
# matplotlib: 3.5.0
# pandas: 1.3.5
# sklearn: 1.0.2

# %%
#Import all required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
#read CSV file from the directory
dataset = pd.read_csv("DIGITAL_MARKETING_PLATFORM_APP_APPLE.csv", sep=",")

# %%
dataset.head(5)
# Out:
#             APP  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  \
# 0    C Compiler        18          2       28     67         4      11
# 1    C Tutorial        12         10       19     69         1      23
# 2   C# Compiler        21         15       32      9        18       2
# 3   C# Tutorial        21         16       27      5         9       1
# 4  C++ Compiler        46         14       29     18        27      10
#
#    SNAPCHAT  YOUTUBE  TIKTOK  EMAIL  OTHER
# 0         1        4       0      0      2
# 1         6        4       0      0      0
# 2         0        7       0      0     12
# 3         0        5       0      0     12
# 4         0       24       0     11     26

# %%
### print dataset description ###
print(dataset.describe())
# Out:
#         FACEBOOK  INSTAGRAM    TWITTER      QUORA   LINKEDIN     REDDIT  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   30.894737   7.789474  21.605263  26.263158   6.763158   6.710526
# std    27.030303   7.425878  16.738916  22.534879   8.062037   9.025214
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     9.750000   1.250000   8.500000   9.000000   0.000000   1.000000
# 50%    21.000000   9.000000  19.500000  21.000000   2.000000   2.000000
# 75%    50.000000  11.750000  30.500000  41.000000  13.000000   7.500000
# max    88.000000  35.000000  72.000000  89.000000  27.000000  37.000000
#
#         SNAPCHAT    YOUTUBE  TIKTOK      EMAIL      OTHER
# count  38.000000  38.000000    38.0  38.000000  38.000000
# mean    0.815789   6.763158     0.0   1.631579   7.000000
# std     1.574377   7.882359     0.0   2.981212   8.898831
# min     0.000000   0.000000     0.0   0.000000   0.000000
# ...

# %%
print(dataset.shape)
# Out:
# (38, 12)

# %%
## Using HISTOGRAM SHAPE & Figsize ##
dataset.hist(figsize=(30,25))
plt.show()

# %%
#Graph 2
dataset.plot(figsize=(30,25))
# Out:
# <AxesSubplot:>

# %%
#Graph3
dataset.plot.box(figsize=(30,25))
# Out:
# <AxesSubplot:>

# %%
## In Matplotlib, we can draw multiple graphs in a single plot in two ways. One is by using subplot() function ##
## here we are using the subplot this parameters allow us to add keywords to each subplot and its default value is None ##

axs = dataset.plot.area(figsize=(30,25), subplots=True)

# %%
 sns.displot(dataset)

# %%
### BAR GRAPH ###
#y = ['FACEBOOK,INSTAGRAM,TWITTER,QUORA,LINKEDIN,REDDIT,SNAPCHAT,YOUTUBE,TIKTOK,EMAIL,OTHER']
#y = dataset.FACEBOOK
plt.figure(figsize=(50,50))
#print(y)
plt.bar(dataset.FACEBOOK, dataset.APP, label="FACEBOOK",color="c",width=.6)
plt.bar(dataset.INSTAGRAM, dataset.APP, label="INSTAGRAM",color="g",width=.6)
plt.legend()
plt.show()

# %%
### SCATTER GRAPH ###

plt.figure(figsize=(100,50))
plt.scatter(dataset.FACEBOOK, dataset.APP, label="FACEBOOK",color="c")
plt.scatter(dataset.INSTAGRAM, dataset.APP, label="INSTAGRAM",color="g")
plt.legend()
plt.show()

# %%
## STACK/AREA PLOT ##

plt.figure(figsize=(50,20))
plt.plot([],[],color='c', label='APP', linewidth=5)
plt.plot([],[],color='g', label='FACEBOOK', linewidth=5)
plt.stackplot(dataset.APP,dataset.FACEBOOK,dataset.INSTAGRAM,colors=['c','g'])
plt.legend()
plt.show()
# Out:
# C:\Users\AMANMI~1\AppData\Local\Temp/ipykernel_11364/261206394.py:6: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.stackplot(dataset.APP,dataset.FACEBOOK,dataset.INSTAGRAM,colors=['c','g'])
# C:\Users\AMANMI~1\AppData\Local\Temp/ipykernel_11364/261206394.py:6: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   plt.stackplot(dataset.APP,dataset.FACEBOOK,dataset.INSTAGRAM,colors=['c','g'])
